# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.tools import add_constant
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier, ExtraTreesClassifier
from joblib import load

from config import EXPERIMENT, RUN_NAME, ARTIFACT_DIR
from logger import logger
from mlflow_utils import evaluate_binary, log_mlflow

# %%
#Tag this cell as 'parameters'
INDEX = 'AAPL'

# %%
# Wrap all this is a parameter diot
run_params = {'experiment' : EXPERIMENT,
              'iteration' : RUN_NAME,
              'index' : INDEX,
              'artifact_dir' : ARTIFACT_DIR}

# %% [markdown]
# Import data

# %%
df = pd.read_csv("./StockPrice1Y/{}.csv".format(INDEX))

# %% [markdown]
# Data prep

# %%
df.columns = [col.lower().replace(" ", "_") for col in df.columns]

# %%
df.sort_values(by = "date", ascending = True, inplace = True)

# %% [markdown]
# Create basic features

# %%
df = df[["date", "open", "adj_close"]].copy()

# %%
df["prev"] = df["adj_close"].shift(1)

# %%
df["sma2"] = df["prev"].rolling(window = 2).mean()
df["sma5"] = df["prev"].rolling(window = 5).mean()
df["sma10"] = df["prev"].rolling(window = 10).mean()
df["sma20"] = df["prev"].rolling(window = 20).mean()

# %%
assert round(df["prev"].tail(5).mean(), 4) == round(df["sma5"].tail(1).item(), 4), 'Expected sma5 to be same as mean of past 5 items'
assert round(df["prev"].tail(10).mean(), 4) == round(df["sma10"].tail(1).item(), 4), 'Expected sma5 to be same as mean of past 10 items'
assert round(df["prev"].tail(20).mean(), 4) == round(df["sma20"].tail(1).item(), 4), 'Expected sma5 to be same as mean of past 20 items'

# %%
df["ema12"] = df["prev"].ewm(span = 12, min_periods = 12, adjust = False).mean()
df["ema26"] = df["prev"].ewm(span = 26, min_periods = 26, adjust = False).mean()

# %%
def difference(prev_price, moving_average):
    return (prev_price - moving_average) / prev_price

# %%
for col in ["sma2", "sma5", "sma10", "sma20", "ema12", "ema26"]:
    df["{}_diff".format(col)] = difference(df["prev"], df[col])

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (224, 16)

# %%
df.drop(columns = ["date", "open"], inplace = True)

# %% [markdown]
# Create label

# %%
df["label"] = (df["adj_close"] > df['prev']).astype(int)

# %% [markdown]
# Train-val split

# %%
#Keep most recent 20days as validation set

# %%
validation_days = 20
train = df.iloc[:-validation_days].copy()
val = df.iloc[-validation_days:].copy()
logger.info('No. of days - Train: {}, Val: {}'.format(train.shape[0], val.shape[0]))
# Out:
# 2023-02-06 18:30:58,470 - No. of days - Train: 204, Val: 20

# %% [markdown]
# Basic visualizations

# %%
plt.figure(figsize = (15, 5))
plt.grid()
plt.plot(train['adj_close'], label = 'price')
plt.plot(train['sma20'], label = 'simple moving average 20')
plt.plot(train['ema12'], label = 'exponential moving average 12')
plt.plot(train['ema26'], label = 'exponential moving average 26')
plt.legend()

# %% [markdown]
# Feature transformations

# %%
scaler = StandardScaler()

# %%
COLS_TO_SCALE = ['prev', 'sma2', 'sma5', 'sma10', 'sma20', 'ema12', 'ema26']

# %%
scaler.fit(train[COLS_TO_SCALE])
# Out:
# StandardScaler()

# %%
train[COLS_TO_SCALE] = scaler.transform(train[COLS_TO_SCALE])
val[COLS_TO_SCALE] = scaler.transform(val[COLS_TO_SCALE])

# %% [markdown]
# Linear regression coefficients

# %%
x_variables = '+'.join(list(train.columns[1:-1]))
logger.info('x variables: {}'.format(x_variables))
# Out:
# 2023-02-06 18:30:59,494 - x variables: prev+sma2+sma5+sma10+sma20+ema12+ema26+sma2_diff+sma5_diff+sma10_diff+sma20_diff+ema12_diff+ema26_diff

# %%
results = smf.ols('adj_close ~ {}'.format(x_variables), data = train).fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              adj_close   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     178.3
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           7.08e-99
# Time:                        18:30:59   Log-Likelihood:                -537.41
# No. Observations:                 204   AIC:                             1103.
# Df Residuals:                     190   BIC:                             1149.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    150.8752      1.450    104.054      0.000     148.015     153.735
# prev         -17.3876     26.255     -0.662      0.509     -69.176      34.401
# sma2          41.3929     45.965      0.901      0.369     -49.274     132.060
# sma5          33.9533     69.534      0.488      0.626    -103.205     171.112
# sma10         10.6912    107.911      0.099      0.921    -202.166     223.548
# sma20         11.8695     66.932      0.177      0.859    -120.156     143.895
# ema12        -80.1282    280.629     -0.286      0.776    -633.676     473.420
# ema26         13.6224     32.596      0.418      0.676     -50.675      77.920
# sma2_diff    513.3876    572.148      0.897      0.371    -615.191    1641.966
# sma5_diff    347.4956    891.423      0.390      0.697   -1410.862    2105.853
# sma10_diff   100.0803   1466.845      0.068      0.946   -2793.313    2993.474
# sma20_diff   107.0935    997.855      0.107      0.915   -1861.204    2075.391
# ema12_diff  -932.6803   4002.472     -0.233      0.816   -8827.669    6962.308
# ema26_diff   215.9037    544.064      0.397      0.692    -857.278    1289.085
# ==============================================================================
# Omnibus:                        2.212   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.331   Jarque-Bera (JB):                1.909
# Skew:                           0.130   Prob(JB):                        0.385
# Kurtosis:                       3.396   Cond. No.                     4.66e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Drop label col

# %%
train.drop(columns = ['adj_close'], inplace = True)
val.drop(columns = ['adj_close'], inplace = True)

# %% [markdown]
# Logistic Regression Coefficients

# %%
y = train['label'].values
X = train.drop(columns = ['label'])

# %%
X = add_constant(X)

# %%
logit = sm.Logit(y, X)

# %%
result = logit.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.670794
#          Iterations 15
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  204
# Model:                          Logit   Df Residuals:                      190
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 06 Feb 2023   Pseudo R-squ.:                 0.03218
# Time:                        18:31:00   Log-Likelihood:                -136.84
# converged:                       True   LL-Null:                       -141.39
# Covariance Type:            nonrobust   LLR p-value:                    0.7653
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5075      0.859     -0.591      0.555      -2.191       1.176
# prev         -10.6646     15.495     -0.688      0.491     -41.034      19.705
# sma2           6.3430     27.154      0.234      0.815     -46.878      59.564
# sma5          -6.9990     40.748     -0.172      0.864     -86.864      72.866
# sma10        -31.1544     63.386     -0.492      0.623    -155.389      93.080
# sma20         -6.0915     39.165     -0.156      0.876     -82.853      70.670
# ema12         56.7435    164.366      0.345      0.730    -265.409     378.896
# ema26         -9.2967     19.201     -0.484      0.628     -46.930      28.336
# sma2_diff     94.9478    338.013      0.281      0.779    -567.546     757.442
# sma5_diff   -122.4104    522.615     -0.234      0.815   -1146.717     901.896
# sma10_diff  -408.4571    861.690     -0.474      0.635   -2097.339    1280.425
# sma20_diff   -91.9097    583.734     -0.157      0.875   -1236.008    1052.189
# ema12_diff   833.5829   2344.637      0.356      0.722   -3761.821    5428.986
# ema26_diff  -173.3838    320.815     -0.540      0.589    -802.170     455.402
# ==============================================================================

# %% [markdown]
# Train some basic models

# %%
y_train = train['label'].values
X_train = train.drop(columns = 'label').values

y_val = val['label'].values
X_val = val.drop(columns = 'label').values

# %%
#Logistic regression
model_name = 'Logistic Regression'
model = LogisticRegression(fit_intercept = False).fit(X_train, y_train)
pred = model.predict_proba(X_val)[:, 1]
log_mlflow(run_params, model, model_name, y_val, pred)
# Out:
# 2023-02-06 18:31:00,726 - AUC: 0.560 | Recall: 0.600 | Precision: 0.750 | F1: 0.667
# 2023-02-06 18:31:00,803 - ROC curve saved to: ../artifact_dir/plots/roc_curve_Logistic Regression (auc = 0.56).png
# 2023-02-06 18:31:00,955 - Precision-recall curve saved to: ../artifact_dir/plots/precision_recall_Logistic Regression (prec = 0.75, recall = 0.60).png
# 2023-02-06 18:31:00,956 - Model saved to: ../artifact_dir/models/Logistic Regression.pickle
# 2023/02/06 18:31:01 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh()
#
# All git commands will error until this is rectified.
#
# This initial warning can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|none|n|0: for no warning or exception
#     - warn|w|warning|1: for a printed warning
#     - error|e|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet

# %%
#Support vector classifier
model_name = 'Support Vector Classifier'
model = SVC(gamma = 2, C = 1, probability = True).fit(X_train, y_train)
pred = model.predict_proba(X_val)[:, 1]
log_mlflow(run_params, model, model_name, y_val, pred)
# Out:
# 2023-02-06 18:31:01,420 - AUC: 0.507 | Recall: 0.667 | Precision: 0.769 | F1: 0.714
# 2023-02-06 18:31:01,496 - ROC curve saved to: ../artifact_dir/plots/roc_curve_Support Vector Classifier (auc = 0.51).png
# 2023-02-06 18:31:01,604 - Precision-recall curve saved to: ../artifact_dir/plots/precision_recall_Support Vector Classifier (prec = 0.77, recall = 0.67).png
# 2023-02-06 18:31:01,605 - Model saved to: ../artifact_dir/models/Support Vector Classifier.pickle

# %%
#K-neighbours
model_name = 'K-nearest Neighbours'
model = KNeighborsClassifier(5).fit(X_train, y_train)
pred = model.predict_proba(X_val)[:, 1]
log_mlflow(run_params, model, model_name, y_val, pred)
# Out:
# 2023-02-06 18:31:01,923 - AUC: 0.533 | Recall: 1.000 | Precision: 0.750 | F1: 0.857
# 2023-02-06 18:31:02,028 - ROC curve saved to: ../artifact_dir/plots/roc_curve_K-nearest Neighbours (auc = 0.53).png
# 2023-02-06 18:31:02,211 - Precision-recall curve saved to: ../artifact_dir/plots/precision_recall_K-nearest Neighbours (prec = 0.75, recall = 1.00).png
# 2023-02-06 18:31:02,212 - Model saved to: ../artifact_dir/models/K-nearest Neighbours.pickle

# %%
#gradient Boosting
model_name = 'Gradient Boosting Machine'
model = GradientBoostingClassifier().fit(X_train, y_train)
pred = model.predict_proba(X_val)[:, 1]
log_mlflow(run_params, model, model_name, y_val, pred)
# Out:
# 2023-02-06 18:31:02,686 - AUC: 0.493 | Recall: 0.067 | Precision: 0.500 | F1: 0.118
# 2023-02-06 18:31:02,762 - ROC curve saved to: ../artifact_dir/plots/roc_curve_Gradient Boosting Machine (auc = 0.49).png
# 2023-02-06 18:31:02,873 - Precision-recall curve saved to: ../artifact_dir/plots/precision_recall_Gradient Boosting Machine (prec = 0.50, recall = 0.07).png
# 2023-02-06 18:31:02,874 - Model saved to: ../artifact_dir/models/Gradient Boosting Machine.pickle

# %%
#Bagged trees
model_name = 'Extra Trees'
model = ExtraTreesClassifier().fit(X_train, y_train)
pred = model.predict_proba(X_val)[:, 1]
log_mlflow(run_params, model, model_name, y_val, pred)
# Out:
# 2023-02-06 18:31:03,355 - AUC: 0.653 | Recall: 0.733 | Precision: 0.786 | F1: 0.759
# 2023-02-06 18:31:03,454 - ROC curve saved to: ../artifact_dir/plots/roc_curve_Extra Trees (auc = 0.65).png
# 2023-02-06 18:31:03,582 - Precision-recall curve saved to: ../artifact_dir/plots/precision_recall_Extra Trees (prec = 0.79, recall = 0.73).png
# 2023-02-06 18:31:03,583 - Model saved to: ../artifact_dir/models/Extra Trees.pickle

# %% [markdown]
# Test loading model

# %%
model_name = 'Support Vector Classifier'
check_model = load('{}/models/{}.pickle'.format(ARTIFACT_DIR, model_name))

# %%
check_model
# Out:
# SVC(C=1, gamma=2, probability=True)

# %%
pred = check_model.predict_proba(X_val)[:, 1]

# %%
evaluate_binary(y_val, pred)
# Out:
# 2023-02-06 18:31:04,370 - AUC: 0.507 | Recall: 0.667 | Precision: 0.769 | F1: 0.714
# (0.5066666666666666,
#  0.6666666666666666,
#  0.7692307692307693,
#  0.7142857142857142)
